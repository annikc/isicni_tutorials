# %%
import numpy as np
import matplotlib.pyplot as plt
from plotFunctions import plotWorld, plotStateValue, plotStateActionValue, plotPolicyPi
from gridworld import GridWorldExample1
from rlagents import RLAgent, RLExampleAgent

# %%
# build and plot world
world = GridWorldExample1()
plotWorld(world,plotNow=False)

# %%
# initialize an agent and run an episode (see program printout)
agent = RLExampleAgent(world)
agent.run_episode()

# plot value functions and policy
plotStateValue(agent.v, world, plotNow=False)
plotStateActionValue(agent.q, world, plotNow=False)
plotPolicyPi(agent.Ppi, world, plotNow=False)

plt.show()
# Out:
# Running episode...
# Step 1: move from (3,0) to (3,1), reward = 0.00
# Step 2: move from (3,1) to (3,0), reward = 0.00
# Step 3: move from (3,0) to (3,1), reward = 0.00
# Step 4: move from (3,1) to (2,1), reward = 0.00
# Step 5: move from (2,1) to (3,1), reward = 0.00
# Step 6: move from (3,1) to (2,1), reward = 0.00
# Step 7: move from (2,1) to (1,1), reward = 0.00
# Step 8: move from (1,1) to (2,1), reward = 0.00
# Step 9: move from (2,1) to (3,1), reward = 0.00
# Step 10: move from (3,1) to (3,0), reward = 0.00
# Step 11: move from (3,0) to (3,1), reward = 0.00
# Step 12: move from (3,1) to (2,1), reward = 0.00
# Step 13: move from (2,1) to (3,1), reward = 0.00
# Step 14: move from (3,1) to (3,0), reward = 0.00
# Step 15: move from (3,0) to (3,1), reward = 0.00
# Step 16: move from (3,1) to (3,0), reward = 0.00
# Step 17: move from (3,0) to (3,1), reward = 0.00
# Step 18: move from (3,1) to (2,1), reward = 0.00
# Step 19: move from (2,1) to (1,1), reward = 0.00
# Step 20: move from (1,1) to (0,1), reward = 0.00
# Step 21: move from (0,1) to (0,2), reward = 0.00
# Step 22: move from (0,2) to (0,1), reward = 0.00
# Step 23: move from (0,1) to (1,1), reward = 0.00
# Step 24: move from (1,1) to (1,0), reward = 0.00
# Step 25: move from (1,0) to (1,1), reward = 0.00
# Step 26: move from (1,1) to (1,0), reward = 0.00
# Step 27: move from (1,0) to (1,1), reward = 0.00
# Step 28: move from (1,1) to (0,1), reward = 0.00
# Step 29: move from (0,1) to (0,2), reward = 0.00
# Step 30: move from (0,2) to (0,3), reward = 0.00
# Step 31: move from (0,3) to (0,2), reward = 0.00
# Step 32: move from (0,2) to (0,3), reward = 0.00
# Step 33: move from (0,3) to (1,3), reward = 0.00
# Step 34: move from (1,3) to (0,3), reward = 0.00
# Step 35: move from (0,3) to (0,4), reward = 0.00
# Step 36: move from (0,4) to (3,0), reward = 0.00
# Step 37: move from (3,0) to (3,1), reward = 0.00
# Step 38: move from (3,1) to (3,0), reward = 0.00
# Step 39: move from (3,0) to (3,1), reward = 0.00
# Step 40: move from (3,1) to (3,0), reward = 0.00
# Step 41: move from (3,0) to (3,1), reward = 0.00
# Step 42: move from (3,1) to (3,0), reward = 0.00
# Step 43: move from (3,0) to (3,1), reward = 0.00
# Step 44: move from (3,1) to (2,1), reward = 0.00
# Step 45: move from (2,1) to (3,1), reward = 0.00
# Step 46: move from (3,1) to (3,0), reward = 0.00
# Step 47: move from (3,0) to (3,1), reward = 0.00
# Step 48: move from (3,1) to (3,0), reward = 0.00
# Step 49: move from (3,0) to (3,1), reward = 0.00
# Step 50: move from (3,1) to (3,0), reward = 0.00
# Step 51: move from (3,0) to (3,1), reward = 0.00
# Step 52: move from (3,1) to (3,0), reward = 0.00
# Step 53: move from (3,0) to (3,1), reward = 0.00
# Step 54: move from (3,1) to (2,1), reward = 0.00
# Step 55: move from (2,1) to (1,1), reward = 0.00
# Step 56: move from (1,1) to (2,1), reward = 0.00
# Step 57: move from (2,1) to (1,1), reward = 0.00
# Step 58: move from (1,1) to (0,1), reward = 0.00
# Step 59: move from (0,1) to (0,2), reward = 0.00
# Step 60: move from (0,2) to (0,3), reward = 0.00
# Step 61: move from (0,3) to (0,2), reward = 0.00
# Step 62: move from (0,2) to (0,3), reward = 0.00
# Step 63: move from (0,3) to (0,4), reward = 0.00
# Step 64: move from (0,4) to (3,0), reward = 0.00
# Step 65: move from (3,0) to (3,1), reward = 0.00
# Step 66: move from (3,1) to (3,0), reward = 0.00
# Step 67: move from (3,0) to (3,1), reward = 0.00
# Step 68: move from (3,1) to (3,0), reward = 0.00
# Step 69: move from (3,0) to (3,1), reward = 0.00
# Step 70: move from (3,1) to (3,0), reward = 0.00
# Step 71: move from (3,0) to (3,1), reward = 0.00
# Step 72: move from (3,1) to (2,1), reward = 0.00
# Step 73: move from (2,1) to (3,1), reward = 0.00
# Step 74: move from (3,1) to (3,0), reward = 0.00
# Step 75: move from (3,0) to (3,1), reward = 0.00
# Step 76: move from (3,1) to (2,1), reward = 0.00
# Step 77: move from (2,1) to (3,1), reward = 0.00
# Step 78: move from (3,1) to (3,0), reward = 0.00
# Step 79: move from (3,0) to (3,1), reward = 0.00
# Step 80: move from (3,1) to (3,0), reward = 0.00
# Step 81: move from (3,0) to (3,1), reward = 0.00
# Step 82: move from (3,1) to (3,0), reward = 0.00
# Step 83: move from (3,0) to (3,1), reward = 0.00
# Step 84: move from (3,1) to (3,0), reward = 0.00
# Step 85: move from (3,0) to (3,1), reward = 0.00
# Step 86: move from (3,1) to (3,0), reward = 0.00
# Step 87: move from (3,0) to (3,1), reward = 0.00
# Step 88: move from (3,1) to (2,1), reward = 0.00
# Step 89: move from (2,1) to (3,1), reward = 0.00
# Step 90: move from (3,1) to (2,1), reward = 0.00
# Step 91: move from (2,1) to (3,1), reward = 0.00
# Step 92: move from (3,1) to (3,0), reward = 0.00
# Step 93: move from (3,0) to (3,1), reward = 0.00
# Step 94: move from (3,1) to (2,1), reward = 0.00
# Step 95: move from (2,1) to (3,1), reward = 0.00
# Step 96: move from (3,1) to (2,1), reward = 0.00
# Step 97: move from (2,1) to (1,1), reward = 0.00
# Step 98: move from (1,1) to (0,1), reward = 0.00
# Step 99: move from (0,1) to (0,2), reward = 0.00
# Step 100: move from (0,2) to (0,1), reward = 0.00
# Step 101: move from (0,1) to (1,1), reward = 0.00
# Step 102: move from (1,1) to (1,0), reward = 0.00
# Step 103: move from (1,0) to (1,1), reward = 0.00
# Step 104: move from (1,1) to (2,1), reward = 0.00
# Step 105: move from (2,1) to (3,1), reward = 0.00
# Step 106: move from (3,1) to (2,1), reward = 0.00
# Step 107: move from (2,1) to (1,1), reward = 0.00
# Step 108: move from (1,1) to (2,1), reward = 0.00
# Step 109: move from (2,1) to (1,1), reward = 0.00
# Step 110: move from (1,1) to (0,1), reward = 0.00
# Step 111: move from (0,1) to (1,1), reward = 0.00
# Step 112: move from (1,1) to (2,1), reward = 0.00
# Step 113: move from (2,1) to (1,1), reward = 0.00
# Step 114: move from (1,1) to (1,0), reward = 0.00
# Step 115: move from (1,0) to (1,1), reward = 0.00
# Step 116: move from (1,1) to (1,0), reward = 0.00
# Step 117: move from (1,0) to (1,1), reward = 0.00
# Step 118: move from (1,1) to (0,1), reward = 0.00
# Step 119: move from (0,1) to (1,1), reward = 0.00
# Step 120: move from (1,1) to (2,1), reward = 0.00
# Step 121: move from (2,1) to (1,1), reward = 0.00
# Step 122: move from (1,1) to (0,1), reward = 0.00
# Step 123: move from (0,1) to (0,2), reward = 0.00
# Step 124: move from (0,2) to (0,1), reward = 0.00
# Step 125: move from (0,1) to (0,2), reward = 0.00
# Step 126: move from (0,2) to (0,1), reward = 0.00
# Step 127: move from (0,1) to (1,1), reward = 0.00
# Step 128: move from (1,1) to (2,1), reward = 0.00
# Step 129: move from (2,1) to (1,1), reward = 0.00
# Step 130: move from (1,1) to (2,1), reward = 0.00
# Step 131: move from (2,1) to (3,1), reward = 0.00
# Step 132: move from (3,1) to (3,0), reward = 0.00
# Step 133: move from (3,0) to (3,1), reward = 0.00
# Step 134: move from (3,1) to (3,0), reward = 0.00
# Step 135: move from (3,0) to (3,1), reward = 0.00
# Step 136: move from (3,1) to (2,1), reward = 0.00
# Step 137: move from (2,1) to (1,1), reward = 0.00
# Step 138: move from (1,1) to (2,1), reward = 0.00
# Step 139: move from (2,1) to (3,1), reward = 0.00
# Step 140: move from (3,1) to (3,0), reward = 0.00
# Step 141: move from (3,0) to (3,1), reward = 0.00
# Step 142: move from (3,1) to (2,1), reward = 0.00
# Step 143: move from (2,1) to (3,1), reward = 0.00
# Step 144: move from (3,1) to (3,0), reward = 0.00
# Step 145: move from (3,0) to (3,1), reward = 0.00
# Step 146: move from (3,1) to (2,1), reward = 0.00
# Step 147: move from (2,1) to (3,1), reward = 0.00
# Step 148: move from (3,1) to (2,1), reward = 0.00
# Step 149: move from (2,1) to (1,1), reward = 0.00
# Step 150: move from (1,1) to (1,0), reward = 0.00
# Step 151: move from (1,0) to (1,1), reward = 0.00
# Step 152: move from (1,1) to (1,0), reward = 0.00
# Step 153: move from (1,0) to (1,1), reward = 0.00
# Step 154: move from (1,1) to (1,0), reward = 0.00
# Step 155: move from (1,0) to (1,1), reward = 0.00
# Step 156: move from (1,1) to (1,0), reward = 0.00
# Step 157: move from (1,0) to (1,1), reward = 0.00
# Step 158: move from (1,1) to (2,1), reward = 0.00
# Step 159: move from (2,1) to (3,1), reward = 0.00
# Step 160: move from (3,1) to (3,0), reward = 0.00
# Step 161: move from (3,0) to (3,1), reward = 0.00
# Step 162: move from (3,1) to (2,1), reward = 0.00
# Step 163: move from (2,1) to (3,1), reward = 0.00
# Step 164: move from (3,1) to (2,1), reward = 0.00
# Step 165: move from (2,1) to (1,1), reward = 0.00
# Step 166: move from (1,1) to (2,1), reward = 0.00
# Step 167: move from (2,1) to (1,1), reward = 0.00
# Step 168: move from (1,1) to (0,1), reward = 0.00
# Step 169: move from (0,1) to (0,2), reward = 0.00
# Step 170: move from (0,2) to (0,1), reward = 0.00
# Step 171: move from (0,1) to (0,2), reward = 0.00
# Step 172: move from (0,2) to (0,1), reward = 0.00
# Step 173: move from (0,1) to (0,2), reward = 0.00
# Step 174: move from (0,2) to (0,3), reward = 0.00
# Step 175: move from (0,3) to (0,4), reward = 0.00
# Step 176: move from (0,4) to (3,0), reward = 0.00
# Step 177: move from (3,0) to (3,1), reward = 0.00
# Step 178: move from (3,1) to (2,1), reward = 0.00
# Step 179: move from (2,1) to (1,1), reward = 0.00
# Step 180: move from (1,1) to (0,1), reward = 0.00
# Step 181: move from (0,1) to (0,2), reward = 0.00
# Step 182: move from (0,2) to (0,3), reward = 0.00
# Step 183: move from (0,3) to (1,3), reward = 0.00
# Step 184: move from (1,3) to (2,3), reward = 0.00
# Step 185: move from (2,3) to (1,3), reward = 0.00
# Step 186: move from (1,3) to (0,3), reward = 0.00
# Step 187: move from (0,3) to (0,2), reward = 0.00
# Step 188: move from (0,2) to (0,3), reward = 0.00
# Step 189: move from (0,3) to (0,4), reward = 0.00
# Step 190: move from (0,4) to (3,0), reward = 0.00
# Step 191: move from (3,0) to (3,1), reward = 0.00
# Step 192: move from (3,1) to (3,0), reward = 0.00
# Step 193: move from (3,0) to (3,1), reward = 0.00
# Step 194: move from (3,1) to (2,1), reward = 0.00
# Step 195: move from (2,1) to (3,1), reward = 0.00
# Step 196: move from (3,1) to (2,1), reward = 0.00
# Step 197: move from (2,1) to (3,1), reward = 0.00
# Step 198: move from (3,1) to (3,0), reward = 0.00
# Step 199: move from (3,0) to (3,1), reward = 0.00
# Step 200: move from (3,1) to (2,1), reward = 0.00
# Step 201: move from (2,1) to (3,1), reward = 0.00
# Step 202: move from (3,1) to (2,1), reward = 0.00
# Step 203: move from (2,1) to (1,1), reward = 0.00
# Step 204: move from (1,1) to (2,1), reward = 0.00
# Step 205: move from (2,1) to (3,1), reward = 0.00
# Step 206: move from (3,1) to (2,1), reward = 0.00
# Step 207: move from (2,1) to (1,1), reward = 0.00
# Step 208: move from (1,1) to (0,1), reward = 0.00
# Step 209: move from (0,1) to (0,2), reward = 0.00
# Step 210: move from (0,2) to (0,1), reward = 0.00
# Step 211: move from (0,1) to (0,2), reward = 0.00
# Step 212: move from (0,2) to (0,3), reward = 0.00
# Step 213: move from (0,3) to (0,4), reward = 0.00
# Step 214: move from (0,4) to (3,0), reward = 0.00
# Step 215: move from (3,0) to (3,1), reward = 0.00
# Step 216: move from (3,1) to (2,1), reward = 0.00
# Step 217: move from (2,1) to (1,1), reward = 0.00
# Step 218: move from (1,1) to (2,1), reward = 0.00
# Step 219: move from (2,1) to (3,1), reward = 0.00
# Step 220: move from (3,1) to (3,0), reward = 0.00
# Step 221: move from (3,0) to (3,1), reward = 0.00
# Step 222: move from (3,1) to (2,1), reward = 0.00
# Step 223: move from (2,1) to (3,1), reward = 0.00
# Step 224: move from (3,1) to (2,1), reward = 0.00
# Step 225: move from (2,1) to (1,1), reward = 0.00
# Step 226: move from (1,1) to (0,1), reward = 0.00
# Step 227: move from (0,1) to (1,1), reward = 0.00
# Step 228: move from (1,1) to (2,1), reward = 0.00
# Step 229: move from (2,1) to (1,1), reward = 0.00
# Step 230: move from (1,1) to (0,1), reward = 0.00
# Step 231: move from (0,1) to (1,1), reward = 0.00
# Step 232: move from (1,1) to (2,1), reward = 0.00
# Step 233: move from (2,1) to (3,1), reward = 0.00
# Step 234: move from (3,1) to (3,0), reward = 0.00
# Step 235: move from (3,0) to (3,1), reward = 0.00
# Step 236: move from (3,1) to (2,1), reward = 0.00
# Step 237: move from (2,1) to (1,1), reward = 0.00
# Step 238: move from (1,1) to (2,1), reward = 0.00
# Step 239: move from (2,1) to (3,1), reward = 0.00
# Step 240: move from (3,1) to (2,1), reward = 0.00
# Step 241: move from (2,1) to (1,1), reward = 0.00
# Step 242: move from (1,1) to (2,1), reward = 0.00
# Step 243: move from (2,1) to (1,1), reward = 0.00
# Step 244: move from (1,1) to (1,0), reward = 0.00
# Step 245: move from (1,0) to (1,1), reward = 0.00
# Step 246: move from (1,1) to (1,0), reward = 0.00
# Step 247: move from (1,0) to (1,1), reward = 0.00
# Step 248: move from (1,1) to (2,1), reward = 0.00
# Step 249: move from (2,1) to (3,1), reward = 0.00
# Step 250: move from (3,1) to (3,0), reward = 0.00
# Step 251: move from (3,0) to (3,1), reward = 0.00
# Step 252: move from (3,1) to (2,1), reward = 0.00
# Step 253: move from (2,1) to (3,1), reward = 0.00
# Step 254: move from (3,1) to (3,0), reward = 0.00
# Step 255: move from (3,0) to (3,1), reward = 0.00
# Step 256: move from (3,1) to (3,0), reward = 0.00
# Step 257: move from (3,0) to (3,1), reward = 0.00
# Step 258: move from (3,1) to (3,0), reward = 0.00
# Step 259: move from (3,0) to (3,1), reward = 0.00
# Step 260: move from (3,1) to (3,0), reward = 0.00
# Step 261: move from (3,0) to (3,1), reward = 0.00
# Step 262: move from (3,1) to (2,1), reward = 0.00
# Step 263: move from (2,1) to (3,1), reward = 0.00
# Step 264: move from (3,1) to (3,0), reward = 0.00
# Step 265: move from (3,0) to (3,1), reward = 0.00
# Step 266: move from (3,1) to (2,1), reward = 0.00
# Step 267: move from (2,1) to (1,1), reward = 0.00
# Step 268: move from (1,1) to (2,1), reward = 0.00
# Step 269: move from (2,1) to (3,1), reward = 0.00
# Step 270: move from (3,1) to (2,1), reward = 0.00
# Step 271: move from (2,1) to (3,1), reward = 0.00
# Step 272: move from (3,1) to (3,0), reward = 0.00
# Step 273: move from (3,0) to (3,1), reward = 0.00
# Step 274: move from (3,1) to (3,0), reward = 0.00
# Step 275: move from (3,0) to (3,1), reward = 0.00
# Step 276: move from (3,1) to (2,1), reward = 0.00
# Step 277: move from (2,1) to (3,1), reward = 0.00
# Step 278: move from (3,1) to (3,0), reward = 0.00
# Step 279: move from (3,0) to (3,1), reward = 0.00
# Step 280: move from (3,1) to (2,1), reward = 0.00
# Step 281: move from (2,1) to (1,1), reward = 0.00
# Step 282: move from (1,1) to (1,0), reward = 0.00
# Step 283: move from (1,0) to (1,1), reward = 0.00
# Step 284: move from (1,1) to (1,0), reward = 0.00
# Step 285: move from (1,0) to (1,1), reward = 0.00
# Step 286: move from (1,1) to (0,1), reward = 0.00
# Step 287: move from (0,1) to (0,2), reward = 0.00
# Step 288: move from (0,2) to (0,1), reward = 0.00
# Step 289: move from (0,1) to (1,1), reward = 0.00
# Step 290: move from (1,1) to (1,0), reward = 0.00
# Step 291: move from (1,0) to (1,1), reward = 0.00
# Step 292: move from (1,1) to (2,1), reward = 0.00
# Step 293: move from (2,1) to (3,1), reward = 0.00
# Step 294: move from (3,1) to (2,1), reward = 0.00
# Step 295: move from (2,1) to (3,1), reward = 0.00
# Step 296: move from (3,1) to (3,0), reward = 0.00
# Step 297: move from (3,0) to (3,1), reward = 0.00
# Step 298: move from (3,1) to (2,1), reward = 0.00
# Step 299: move from (2,1) to (1,1), reward = 0.00
# Step 300: move from (1,1) to (0,1), reward = 0.00
# Step 301: move from (0,1) to (1,1), reward = 0.00
# Step 302: move from (1,1) to (1,0), reward = 0.00
# Step 303: move from (1,0) to (1,1), reward = 0.00
# Step 304: move from (1,1) to (0,1), reward = 0.00
# Step 305: move from (0,1) to (1,1), reward = 0.00
# Step 306: move from (1,1) to (0,1), reward = 0.00
# Step 307: move from (0,1) to (1,1), reward = 0.00
# Step 308: move from (1,1) to (1,0), reward = 0.00
# Step 309: move from (1,0) to (1,1), reward = 0.00
# Step 310: move from (1,1) to (1,0), reward = 0.00
# Step 311: move from (1,0) to (1,1), reward = 0.00
# Step 312: move from (1,1) to (2,1), reward = 0.00
# Step 313: move from (2,1) to (3,1), reward = 0.00
# Step 314: move from (3,1) to (3,0), reward = 0.00
# Step 315: move from (3,0) to (3,1), reward = 0.00
# Step 316: move from (3,1) to (3,0), reward = 0.00
# Step 317: move from (3,0) to (3,1), reward = 0.00
# Step 318: move from (3,1) to (3,0), reward = 0.00
# Step 319: move from (3,0) to (3,1), reward = 0.00
# Step 320: move from (3,1) to (3,0), reward = 0.00
# Step 321: move from (3,0) to (3,1), reward = 0.00
# Step 322: move from (3,1) to (3,0), reward = 0.00
# Step 323: move from (3,0) to (3,1), reward = 0.00
# Step 324: move from (3,1) to (3,0), reward = 0.00
# Step 325: move from (3,0) to (3,1), reward = 0.00
# Step 326: move from (3,1) to (3,0), reward = 0.00
# Step 327: move from (3,0) to (3,1), reward = 0.00
# Step 328: move from (3,1) to (2,1), reward = 0.00
# Step 329: move from (2,1) to (3,1), reward = 0.00
# Step 330: move from (3,1) to (3,0), reward = 0.00
# Step 331: move from (3,0) to (3,1), reward = 0.00
# Step 332: move from (3,1) to (2,1), reward = 0.00
# Step 333: move from (2,1) to (1,1), reward = 0.00
# Step 334: move from (1,1) to (0,1), reward = 0.00
# Step 335: move from (0,1) to (0,2), reward = 0.00
# Step 336: move from (0,2) to (0,3), reward = 0.00
# Step 337: move from (0,3) to (0,4), reward = 0.00
# Step 338: move from (0,4) to (3,0), reward = 0.00
# Step 339: move from (3,0) to (3,1), reward = 0.00
# Step 340: move from (3,1) to (2,1), reward = 0.00
# Step 341: move from (2,1) to (3,1), reward = 0.00
# Step 342: move from (3,1) to (2,1), reward = 0.00
# Step 343: move from (2,1) to (1,1), reward = 0.00
# Step 344: move from (1,1) to (0,1), reward = 0.00
# Step 345: move from (0,1) to (0,2), reward = 0.00
# Step 346: move from (0,2) to (0,1), reward = 0.00
# Step 347: move from (0,1) to (0,2), reward = 0.00
# Step 348: move from (0,2) to (0,1), reward = 0.00
# Step 349: move from (0,1) to (1,1), reward = 0.00
# Step 350: move from (1,1) to (1,0), reward = 0.00
# Step 351: move from (1,0) to (1,1), reward = 0.00
# Step 352: move from (1,1) to (0,1), reward = 0.00
# Step 353: move from (0,1) to (0,2), reward = 0.00
# Step 354: move from (0,2) to (0,3), reward = 0.00
# Step 355: move from (0,3) to (0,4), reward = 0.00
# Step 356: move from (0,4) to (3,0), reward = 0.00
# Step 357: move from (3,0) to (3,1), reward = 0.00
# Step 358: move from (3,1) to (3,0), reward = 0.00
# Step 359: move from (3,0) to (3,1), reward = 0.00
# Step 360: move from (3,1) to (2,1), reward = 0.00
# Step 361: move from (2,1) to (1,1), reward = 0.00
# Step 362: move from (1,1) to (2,1), reward = 0.00
# Step 363: move from (2,1) to (1,1), reward = 0.00
# Step 364: move from (1,1) to (2,1), reward = 0.00
# Step 365: move from (2,1) to (1,1), reward = 0.00
# Step 366: move from (1,1) to (1,0), reward = 0.00
# Step 367: move from (1,0) to (1,1), reward = 0.00
# Step 368: move from (1,1) to (1,0), reward = 0.00
# Step 369: move from (1,0) to (1,1), reward = 0.00
# Step 370: move from (1,1) to (2,1), reward = 0.00
# Step 371: move from (2,1) to (3,1), reward = 0.00
# Step 372: move from (3,1) to (2,1), reward = 0.00
# Step 373: move from (2,1) to (1,1), reward = 0.00
# Step 374: move from (1,1) to (0,1), reward = 0.00
# Step 375: move from (0,1) to (1,1), reward = 0.00
# Step 376: move from (1,1) to (1,0), reward = 0.00
# Step 377: move from (1,0) to (1,1), reward = 0.00
# Step 378: move from (1,1) to (1,0), reward = 0.00
# Step 379: move from (1,0) to (1,1), reward = 0.00
# Step 380: move from (1,1) to (2,1), reward = 0.00
# Step 381: move from (2,1) to (1,1), reward = 0.00
# Step 382: move from (1,1) to (2,1), reward = 0.00
# Step 383: move from (2,1) to (1,1), reward = 0.00
# Step 384: move from (1,1) to (0,1), reward = 0.00
# Step 385: move from (0,1) to (1,1), reward = 0.00
# Step 386: move from (1,1) to (1,0), reward = 0.00
# Step 387: move from (1,0) to (1,1), reward = 0.00
# Step 388: move from (1,1) to (1,0), reward = 0.00
# Step 389: move from (1,0) to (1,1), reward = 0.00
# Step 390: move from (1,1) to (2,1), reward = 0.00
# Step 391: move from (2,1) to (3,1), reward = 0.00
# Step 392: move from (3,1) to (2,1), reward = 0.00
# Step 393: move from (2,1) to (1,1), reward = 0.00
# Step 394: move from (1,1) to (0,1), reward = 0.00
# Step 395: move from (0,1) to (0,2), reward = 0.00
# Step 396: move from (0,2) to (0,3), reward = 0.00
# Step 397: move from (0,3) to (0,2), reward = 0.00
# Step 398: move from (0,2) to (0,3), reward = 0.00
# Step 399: move from (0,3) to (0,4), reward = 0.00
# Step 400: move from (0,4) to (3,0), reward = 0.00
# Step 401: move from (3,0) to (3,1), reward = 0.00
# Step 402: move from (3,1) to (3,0), reward = 0.00
# Step 403: move from (3,0) to (3,1), reward = 0.00
# Step 404: move from (3,1) to (3,0), reward = 0.00
# Step 405: move from (3,0) to (3,1), reward = 0.00
# Step 406: move from (3,1) to (2,1), reward = 0.00
# Step 407: move from (2,1) to (3,1), reward = 0.00
# Step 408: move from (3,1) to (2,1), reward = 0.00
# Step 409: move from (2,1) to (3,1), reward = 0.00
# Step 410: move from (3,1) to (2,1), reward = 0.00
# Step 411: move from (2,1) to (1,1), reward = 0.00
# Step 412: move from (1,1) to (2,1), reward = 0.00
# Step 413: move from (2,1) to (1,1), reward = 0.00
# Step 414: move from (1,1) to (0,1), reward = 0.00
# Step 415: move from (0,1) to (1,1), reward = 0.00
# Step 416: move from (1,1) to (2,1), reward = 0.00
# Step 417: move from (2,1) to (1,1), reward = 0.00
# Step 418: move from (1,1) to (2,1), reward = 0.00
# Step 419: move from (2,1) to (3,1), reward = 0.00
# Step 420: move from (3,1) to (3,0), reward = 0.00
# Step 421: move from (3,0) to (3,1), reward = 0.00
# Step 422: move from (3,1) to (3,0), reward = 0.00
# Step 423: move from (3,0) to (3,1), reward = 0.00
# Step 424: move from (3,1) to (2,1), reward = 0.00
# Step 425: move from (2,1) to (1,1), reward = 0.00
# Step 426: move from (1,1) to (1,0), reward = 0.00
# Step 427: move from (1,0) to (1,1), reward = 0.00
# Step 428: move from (1,1) to (1,0), reward = 0.00
# Step 429: move from (1,0) to (1,1), reward = 0.00
# Step 430: move from (1,1) to (2,1), reward = 0.00
# Step 431: move from (2,1) to (3,1), reward = 0.00
# Step 432: move from (3,1) to (2,1), reward = 0.00
# Step 433: move from (2,1) to (1,1), reward = 0.00
# Step 434: move from (1,1) to (0,1), reward = 0.00
# Step 435: move from (0,1) to (1,1), reward = 0.00
# Step 436: move from (1,1) to (1,0), reward = 0.00
# Step 437: move from (1,0) to (1,1), reward = 0.00
# Step 438: move from (1,1) to (2,1), reward = 0.00
# Step 439: move from (2,1) to (1,1), reward = 0.00
# Step 440: move from (1,1) to (0,1), reward = 0.00
# Step 441: move from (0,1) to (1,1), reward = 0.00
# Step 442: move from (1,1) to (1,0), reward = 0.00
# Step 443: move from (1,0) to (1,1), reward = 0.00
# Step 444: move from (1,1) to (0,1), reward = 0.00
# Step 445: move from (0,1) to (0,2), reward = 0.00
# Step 446: move from (0,2) to (0,1), reward = 0.00
# Step 447: move from (0,1) to (1,1), reward = 0.00
# Step 448: move from (1,1) to (2,1), reward = 0.00
# Step 449: move from (2,1) to (3,1), reward = 0.00
# Step 450: move from (3,1) to (2,1), reward = 0.00
# Step 451: move from (2,1) to (1,1), reward = 0.00
# Step 452: move from (1,1) to (2,1), reward = 0.00
# Step 453: move from (2,1) to (3,1), reward = 0.00
# Step 454: move from (3,1) to (3,0), reward = 0.00
# Step 455: move from (3,0) to (3,1), reward = 0.00
# Step 456: move from (3,1) to (3,0), reward = 0.00
# Step 457: move from (3,0) to (3,1), reward = 0.00
# Step 458: move from (3,1) to (3,0), reward = 0.00
# Step 459: move from (3,0) to (3,1), reward = 0.00
# Step 460: move from (3,1) to (2,1), reward = 0.00
# Step 461: move from (2,1) to (1,1), reward = 0.00
# Step 462: move from (1,1) to (0,1), reward = 0.00
# Step 463: move from (0,1) to (0,2), reward = 0.00
# Step 464: move from (0,2) to (0,1), reward = 0.00
# Step 465: move from (0,1) to (0,2), reward = 0.00
# Step 466: move from (0,2) to (0,3), reward = 0.00
# Step 467: move from (0,3) to (1,3), reward = 0.00
# Step 468: move from (1,3) to (2,3), reward = 0.00
# Step 469: move from (2,3) to (1,3), reward = 0.00
# Step 470: move from (1,3) to (0,3), reward = 0.00
# Step 471: move from (0,3) to (0,4), reward = 0.00
# Step 472: move from (0,4) to (3,0), reward = 0.00
# Step 473: move from (3,0) to (3,1), reward = 0.00
# Step 474: move from (3,1) to (2,1), reward = 0.00
# Step 475: move from (2,1) to (1,1), reward = 0.00
# Step 476: move from (1,1) to (2,1), reward = 0.00
# Step 477: move from (2,1) to (3,1), reward = 0.00
# Step 478: move from (3,1) to (3,0), reward = 0.00
# Step 479: move from (3,0) to (3,1), reward = 0.00
# Step 480: move from (3,1) to (2,1), reward = 0.00
# Step 481: move from (2,1) to (3,1), reward = 0.00
# Step 482: move from (3,1) to (3,0), reward = 0.00
# Step 483: move from (3,0) to (3,1), reward = 0.00
# Step 484: move from (3,1) to (3,0), reward = 0.00
# Step 485: move from (3,0) to (3,1), reward = 0.00
# Step 486: move from (3,1) to (2,1), reward = 0.00
# Step 487: move from (2,1) to (3,1), reward = 0.00
# Step 488: move from (3,1) to (2,1), reward = 0.00
# Step 489: move from (2,1) to (3,1), reward = 0.00
# Step 490: move from (3,1) to (2,1), reward = 0.00
# Step 491: move from (2,1) to (3,1), reward = 0.00
# Step 492: move from (3,1) to (2,1), reward = 0.00
# Step 493: move from (2,1) to (3,1), reward = 0.00
# Step 494: move from (3,1) to (3,0), reward = 0.00
# Step 495: move from (3,0) to (3,1), reward = 0.00
# Step 496: move from (3,1) to (3,0), reward = 0.00
# Step 497: move from (3,0) to (3,1), reward = 0.00
# Step 498: move from (3,1) to (3,0), reward = 0.00
# Step 499: move from (3,0) to (3,1), reward = 0.00
# Step 500: move from (3,1) to (3,0), reward = 0.00
# Step 501: move from (3,0) to (3,1), reward = 0.00
# Step 502: move from (3,1) to (3,0), reward = 0.00
# Step 503: move from (3,0) to (3,1), reward = 0.00
# Step 504: move from (3,1) to (3,0), reward = 0.00
# Step 505: move from (3,0) to (3,1), reward = 0.00
# Step 506: move from (3,1) to (2,1), reward = 0.00
# Step 507: move from (2,1) to (1,1), reward = 0.00
# Step 508: move from (1,1) to (0,1), reward = 0.00
# Step 509: move from (0,1) to (1,1), reward = 0.00
# Step 510: move from (1,1) to (2,1), reward = 0.00
# Step 511: move from (2,1) to (3,1), reward = 0.00
# Step 512: move from (3,1) to (2,1), reward = 0.00
# Step 513: move from (2,1) to (3,1), reward = 0.00
# Step 514: move from (3,1) to (2,1), reward = 0.00
# Step 515: move from (2,1) to (1,1), reward = 0.00
# Step 516: move from (1,1) to (1,0), reward = 0.00
# Step 517: move from (1,0) to (1,1), reward = 0.00
# Step 518: move from (1,1) to (1,0), reward = 0.00
# Step 519: move from (1,0) to (1,1), reward = 0.00
# Step 520: move from (1,1) to (0,1), reward = 0.00
# Step 521: move from (0,1) to (0,2), reward = 0.00
# Step 522: move from (0,2) to (0,1), reward = 0.00
# Step 523: move from (0,1) to (1,1), reward = 0.00
# Step 524: move from (1,1) to (0,1), reward = 0.00
# Step 525: move from (0,1) to (1,1), reward = 0.00
# Step 526: move from (1,1) to (0,1), reward = 0.00
# Step 527: move from (0,1) to (1,1), reward = 0.00
# Step 528: move from (1,1) to (1,0), reward = 0.00
# Step 529: move from (1,0) to (1,1), reward = 0.00
# Step 530: move from (1,1) to (1,0), reward = 0.00
# Step 531: move from (1,0) to (1,1), reward = 0.00
# Step 532: move from (1,1) to (1,0), reward = 0.00
# Step 533: move from (1,0) to (1,1), reward = 0.00
# Step 534: move from (1,1) to (0,1), reward = 0.00
# Step 535: move from (0,1) to (0,2), reward = 0.00
# Step 536: move from (0,2) to (0,3), reward = 0.00
# Step 537: move from (0,3) to (0,4), reward = 0.00
# Step 538: move from (0,4) to (3,0), reward = 0.00
# Step 539: move from (3,0) to (3,1), reward = 0.00
# Step 540: move from (3,1) to (2,1), reward = 0.00
# Step 541: move from (2,1) to (1,1), reward = 0.00
# Step 542: move from (1,1) to (2,1), reward = 0.00
# Step 543: move from (2,1) to (3,1), reward = 0.00
# Step 544: move from (3,1) to (2,1), reward = 0.00
# Step 545: move from (2,1) to (1,1), reward = 0.00
# Step 546: move from (1,1) to (0,1), reward = 0.00
# Step 547: move from (0,1) to (0,2), reward = 0.00
# Step 548: move from (0,2) to (0,1), reward = 0.00
# Step 549: move from (0,1) to (1,1), reward = 0.00
# Step 550: move from (1,1) to (1,0), reward = 0.00
# Step 551: move from (1,0) to (1,1), reward = 0.00
# Step 552: move from (1,1) to (1,0), reward = 0.00
# Step 553: move from (1,0) to (1,1), reward = 0.00
# Step 554: move from (1,1) to (0,1), reward = 0.00
# Step 555: move from (0,1) to (0,2), reward = 0.00
# Step 556: move from (0,2) to (0,1), reward = 0.00
# Step 557: move from (0,1) to (0,2), reward = 0.00
# Step 558: move from (0,2) to (0,3), reward = 0.00
# Step 559: move from (0,3) to (1,3), reward = 0.00
# Step 560: move from (1,3) to (0,3), reward = 0.00
# Step 561: move from (0,3) to (0,2), reward = 0.00
# Step 562: move from (0,2) to (0,3), reward = 0.00
# Step 563: move from (0,3) to (1,3), reward = 0.00
# Step 564: move from (1,3) to (2,3), reward = 0.00
# Step 565: move from (2,3) to (3,3), reward = 0.00
# Step 566: move from (3,3) to (2,3), reward = 1.00
# Step 567: move from (2,3) to (1,3), reward = 0.00
# Step 568: move from (1,3) to (2,3), reward = 0.00
# Step 569: move from (2,3) to (1,3), reward = 0.00
# Step 570: move from (1,3) to (2,3), reward = 0.00
# Step 571: move from (2,3) to (1,3), reward = 0.00
# Step 572: move from (1,3) to (2,3), reward = 0.00
# Step 573: move from (2,3) to (1,3), reward = 0.00
# Step 574: move from (1,3) to (2,3), reward = 0.00
# Step 575: move from (2,3) to (3,3), reward = 0.00
# Step 576: move from (3,3) to (3,4), reward = 1.00
# Terminated.
